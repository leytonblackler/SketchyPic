# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
import os
import time
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %%
BUFFER_SIZE = 400
BATCH_SIZE = 32
IMG_WIDTH = 256
IMG_HEIGHT = 256

# The percentage of all photo-sketch image pairs allocated to training (remainder is used for testing).
TRAINING_DATASET_SIZE = 0.9

PHOTO_FOLDER_PATH = '../sketchy_database/256x256/photo/tx_000100000000/'
SKETCH_FOLDER_PATH = '../sketchy_database/256x256/sketch/tx_000100000000/'

# %%
def get_category_names():
    directories = [x[1] for x in os.walk(PHOTO_FOLDER_PATH)]
    non_empty_dirs = [x for x in directories if x]
    return [item for subitem in non_empty_dirs for item in subitem]

# %%
def get_file_names(folder_path, category):
    return os.listdir(folder_path + category)

# %%
def load_image_pair(photo_file_path, sketch_file_path):
    photo = tf.io.read_file(photo_file_path)
    photo = tf.image.decode_jpeg(photo)
    photo = tf.cast(photo, tf.float32)
    
    sketch = tf.io.read_file(sketch_file_path)
    sketch = tf.image.decode_jpeg(sketch)
    sketch = tf.cast(sketch, tf.float32)
    
    return photo, sketch

# %%
all_photo_file_paths = []
all_sketch_file_paths = []

# Get the category names based on the names of the subfolders in the sketchy database.
category_names = get_category_names()
category_count = 1

# Iterate across each of the category names (e.g. airplane, alarm_clock, ant, etc.)
for category_name in category_names:
    print('[' + str(category_count) + '/' + str(len(category_names)) + '] Loading data for category: ' + category_name)
    
    # Create a list containing all the file names of photos from the current category.
    photo_file_names = get_file_names(PHOTO_FOLDER_PATH, category_name)
    
    # Create a list containing all the file names of sketches from the current category.
    sketch_file_names = get_file_names(SKETCH_FOLDER_PATH, category_name)
    
    # Iterate across each of the photo files.
    for photo_file_name in photo_file_names:
        
        # Define the function that will be used to determine if a sketch file is a pair to the current photo file.
        def filterFunction(file_name):
            if file_name[:-6] == photo_file_name[:-4]:
                return True
            else:
                return False

        # Use the filter function to create a new list containing the file names of sketches that are a pair to the current photo file.
        sketch_pair_file_names = list(filter(filterFunction, sketch_file_names))
        
        for sketch_file_name in sketch_pair_file_names:
            all_photo_file_paths.append(PHOTO_FOLDER_PATH + category_name + '/' + photo_file_name)
            all_sketch_file_paths.append(SKETCH_FOLDER_PATH + category_name + '/' + sketch_file_name)

    category_count += 1

total_image_pairs = len(all_photo_file_paths)
print("Total photo-sketch image pairs: " + str(total_image_pairs))

# Create a combined dataset including the file names of both the photos and sketches.
all_dataset = tf.data.Dataset.from_tensor_slices((all_photo_file_paths, all_sketch_file_paths))

# Shuffle the dataset (batch size is the total number of images so the categories are sufficiently mixed together).
# (Having a smaller batch size, e.g. 400, would only shuffle the first 400 images amongst eachother, then the next 400, etc)
all_dataset = all_dataset.shuffle(total_image_pairs)

# Applies the load_image_pair function to each pair of file names, resulting in the dataset becoming pairs of actual images.
all_dataset = all_dataset.map(load_image_pair, num_parallel_calls=tf.data.experimental.AUTOTUNE)

# Calculate the number of photo-sketch image pairs to allocate to the training dataset based on the supplied parameter.
train_dataset_size = int(round(TRAINING_DATASET_SIZE * total_image_pairs))

# Allocate a percentage of all photo-sketch image pairs into a dataset for training.
print("Creating training dataset with " + str(train_dataset_size) + " image pairs.")
training_dataset = all_dataset.take(train_dataset_size)

# Allocate a percentage of all photo-sketch image pairs into a dataset for training.
print("Creating testing dataset with " + str(total_image_pairs - train_dataset_size) + " image pairs.")
test_dataset = all_dataset.skip(train_dataset_size)

count = 0
for photo, sketch in training_dataset:
    plt.figure()
    plt.imshow(photo/255.0)
    plt.figure()
    plt.imshow(sketch/255.0)
    count += 1
    if count == 15:
        break
# Out:
# [1/125] Loading data for category: door
# [2/125] Loading data for category: tiger
# [3/125] Loading data for category: sheep
# [4/125] Loading data for category: car_(sedan)
# [5/125] Loading data for category: seal
# [6/125] Loading data for category: bee
# [7/125] Loading data for category: knife
# [8/125] Loading data for category: zebra
# [9/125] Loading data for category: seagull
# [10/125] Loading data for category: hot-air_balloon
# [11/125] Loading data for category: crocodilian
# [12/125] Loading data for category: flower
# [13/125] Loading data for category: sailboat
# [14/125] Loading data for category: apple
# [15/125] Loading data for category: eyeglasses
# [16/125] Loading data for category: giraffe
# [17/125] Loading data for category: hammer
# [18/125] Loading data for category: bread
# [19/125] Loading data for category: pig
# [20/125] Loading data for category: bat
# [21/125] Loading data for category: kangaroo
# [22/125] Loading data for category: piano
# [23/125] Loading data for category: teapot
# [24/125] Loading data for category: wine_bottle
# [25/125] Loading data for category: blimp
# [26/125] Loading data for category: armor
# [27/125] Loading data for category: elephant
# [28/125] Loading data for category: table
# [29/125] Loading data for category: rhinoceros
# [30/125] Loading data for category: chair
# [31/125] Loading data for category: airplane
# [32/125] Loading data for category: penguin
# [33/125] Loading data for category: sea_turtle
# [34/125] Loading data for category: snail
# [35/125] Loading data for category: guitar
# [36/125] Loading data for category: mouse
# [37/125] Loading data for category: scissors
# [38/125] Loading data for category: tree
# [39/125] Loading data for category: hedgehog
# [40/125] Loading data for category: bear
# [41/125] Loading data for category: crab
# [42/125] Loading data for category: lizard
# [43/125] Loading data for category: pear
# [44/125] Loading data for category: snake
# [45/125] Loading data for category: helicopter
# [46/125] Loading data for category: rocket
# [47/125] Loading data for category: mushroom
# [48/125] Loading data for category: pretzel
# [49/125] Loading data for category: lion
# [50/125] Loading data for category: spider
# [51/125] Loading data for category: umbrella
# [52/125] Loading data for category: squirrel
# [53/125] Loading data for category: fan
# [54/125] Loading data for category: hotdog
# [55/125] Loading data for category: candle
# [56/125] Loading data for category: beetle
# [57/125] Loading data for category: duck
# [58/125] Loading data for category: dog
# [59/125] Loading data for category: geyser
# [60/125] Loading data for category: alarm_clock
# [61/125] Loading data for category: jack-o-lantern
# [62/125] Loading data for category: starfish
# [63/125] Loading data for category: ray
# [64/125] Loading data for category: frog
# [65/125] Loading data for category: pickup_truck
# [66/125] Loading data for category: shoe
# [67/125] Loading data for category: cat
# [68/125] Loading data for category: songbird
# [69/125] Loading data for category: trumpet
# [70/125] Loading data for category: teddy_bear
# [71/125] Loading data for category: windmill
# [72/125] Loading data for category: shark
# [73/125] Loading data for category: ant
# [74/125] Loading data for category: lobster
# [75/125] Loading data for category: fish
# [76/125] Loading data for category: deer
# [77/125] Loading data for category: saxophone
# [78/125] Loading data for category: strawberry
# [79/125] Loading data for category: pistol
# [80/125] Loading data for category: ape
# [81/125] Loading data for category: hermit_crab
# [82/125] Loading data for category: pizza
# [83/125] Loading data for category: scorpion
# [84/125] Loading data for category: violin
# [85/125] Loading data for category: swan
# [86/125] Loading data for category: parrot
# [87/125] Loading data for category: pineapple
# [88/125] Loading data for category: tank
# [89/125] Loading data for category: cup
# [90/125] Loading data for category: couch
# [91/125] Loading data for category: saw
# [92/125] Loading data for category: hamburger
# [93/125] Loading data for category: horse
# [94/125] Loading data for category: rifle
# [95/125] Loading data for category: hourglass
# [96/125] Loading data for category: dolphin
# [97/125] Loading data for category: raccoon
# [98/125] Loading data for category: rabbit
# [99/125] Loading data for category: wheelchair
# [100/125] Loading data for category: camel
# [101/125] Loading data for category: wading_bird
# [102/125] Loading data for category: skyscraper
# [103/125] Loading data for category: butterfly
# [104/125] Loading data for category: sword
# [105/125] Loading data for category: castle
# [106/125] Loading data for category: church
# [107/125] Loading data for category: chicken
# [108/125] Loading data for category: hat
# [109/125] Loading data for category: bicycle
# [110/125] Loading data for category: cabin
# [111/125] Loading data for category: motorcycle
# [112/125] Loading data for category: racket
# [113/125] Loading data for category: window
# [114/125] Loading data for category: turtle
# [115/125] Loading data for category: banana
# [116/125] Loading data for category: cow
# [117/125] Loading data for category: owl
# [118/125] Loading data for category: bench
# [119/125] Loading data for category: spoon
# [120/125] Loading data for category: bell
# [121/125] Loading data for category: jellyfish
# [122/125] Loading data for category: axe
# [123/125] Loading data for category: harp
# [124/125] Loading data for category: cannon
# [125/125] Loading data for category: volcano
# Total photo-sketch image pairs: 74609
# Creating training dataset with 67148 image pairs.
# Creating testing dataset with 7461 image pairs.
# /home/leytonblackler/anaconda3/envs/tensorflow_gpuenv/lib/python3.5/site-packages/matplotlib/pyplot.py:513: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
